# %%
import os, sys
import numpy as np
import tensorflow as tf
import neurite as ne
import skimage
import voxelmorph as vxm
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6565/4282277595.py in <module>
#       1 import os, sys
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 import neurite as ne
#       5 import skimage
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# # Load data

# %%
# load MNIST data. 
# `mnist.load_data()` already splits our data into train and test.  
(x_train_load, y_train_load), (x_test_load, y_test_load) = mnist.load_data()

digit_sel = 5

# extract only instances of the digit 5
x_train = x_train_load[y_train_load==digit_sel, ...]
y_train = y_train_load[y_train_load==digit_sel]
x_test = x_test_load[y_test_load==digit_sel, ...]
y_test = y_test_load[y_test_load==digit_sel]

# let's get some shapes to understand what we loaded.
print('shape of x_train: {}, y_train: {}'.format(x_train.shape, y_train.shape))
# Out:
# shape of x_train: (5421, 28, 28), y_train: (5421,)

# %%
nb_val = 1000  # keep 1,000 subjects for validation
x_val = x_train[-nb_val:, ...]  # this indexing means "the last nb_val entries" of the zeroth axis
y_val = y_train[-nb_val:]
x_train = x_train[:-nb_val, ...]
y_train = y_train[:-nb_val]

# %% [markdown]
# # Visualisation

# %% [markdown]
# Map pixel intensity to [0,1]

# %%
# fix data
x_train = x_train.astype('float')/255
x_val = x_val.astype('float')/255
x_test = x_test.astype('float')/255

# verify
print('training maximum value', x_train.max())
# Out:
# training maximum value 1.0

# %% [markdown]
# Visualise some examples

# %%
nb_vis = 5

# choose nb_vis sample indexes
idx = np.random.choice(x_train.shape[0], nb_vis, replace=False)
example_digits = [f for f in x_train[idx, ...]]

# plot
ne.plot.slices(example_digits, cmaps=['gray'], do_colorbars=True);

# %% [markdown]
# Add some padding because NN likes input of shape $2^n$

# %%
pad_amount = ((0, 0), (2,2), (2,2))

# fix data
x_train = np.pad(x_train, pad_amount, 'constant')
x_val = np.pad(x_val, pad_amount, 'constant')
x_test = np.pad(x_test, pad_amount, 'constant')

# verify
print('shape of training data', x_train.shape)
# Out:
# shape of training data (4421, 32, 32)

# %% [markdown]
# # Build Model

# %% [markdown]
# ### Input definition

# %%
# configure unet input shape (concatenation of moving and fixed images)
ndim = 2
unet_input_features = 2
inshape = (*x_train.shape[1:], unet_input_features)

# configure unet features 
nb_features = [
    [32, 32, 32, 32],         # encoder features
    [32, 32, 32, 32, 32, 16]  # decoder features
]

# %% [markdown]
# ### Loss definition

# %%
# voxelmorph has a variety of custom loss classes
losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]

# usually, we have to balance the two losses by a hyper-parameter
lambda_param = 0.05
loss_weights = [1, lambda_param]

# %% [markdown]
# ### Model Initialisation

# %%
# build model using VxmDense
inshape = x_train.shape[1:]
vxm_model = vxm.networks.VxmDense(inshape, nb_features, int_steps=0)
# Out:
# WARNING:tensorflow:From C:\Users\jerem\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:620: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %% [markdown]
# # Training

# %%
def vxm_data_generator(x_data, batch_size=32):
    """
    Generator that takes in data of size [N, H, W], and yields data for
    our custom vxm model. Note that we need to provide numpy data for each
    input, and each output.

    inputs:  moving [bs, H, W, 1], fixed image [bs, H, W, 1]
    outputs: moved image [bs, H, W, 1], zero-gradient [bs, H, W, 2]
    """

    # preliminary sizing
    vol_shape = x_data.shape[1:] # extract data shape
    ndims = len(vol_shape)
    
    # prepare a zero array the size of the deformation
    # we'll explain this below
    zero_phi = np.zeros([batch_size, *vol_shape, ndims])
    
    while True:
        # prepare inputs:
        # images need to be of the size [batch_size, H, W, 1]
        idx1 = np.random.randint(0, x_data.shape[0], size=batch_size)
        moving_images = x_data[idx1, ..., np.newaxis]
        idx2 = np.random.randint(0, x_data.shape[0], size=batch_size)
        fixed_images = x_data[idx2, ..., np.newaxis]
        inputs = [moving_images, fixed_images]
        
        # prepare outputs (the 'true' moved image):
        # of course, we don't have this, but we know we want to compare 
        # the resulting moved image with the fixed image. 
        # we also wish to penalize the deformation field. 
        outputs = [fixed_images, zero_phi]
        
        yield (inputs, outputs)

# %%
# let's test it
train_generator = vxm_data_generator(x_train)
in_sample, out_sample = next(train_generator)

# visualize
images = [img[0, :, :, 0] for img in in_sample + out_sample] 
titles = ['moving', 'fixed', 'moved ground-truth (fixed)', 'zeros']
ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
nb_epochs = 10
steps_per_epoch = 100
hist = vxm_model.fit_generator(train_generator, epochs=nb_epochs, steps_per_epoch=steps_per_epoch, verbose=2);
# Out:
# <ipython-input-14-2cf1a25db3a8>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = vxm_model.fit_generator(train_generator, epochs=nb_epochs, steps_per_epoch=steps_per_epoch, verbose=2);
# Epoch 1/10
# 100/100 - 26s - loss: 0.0498 - transformer_loss: 0.0470 - flow_loss: 0.0559 - 26s/epoch - 257ms/step
# Epoch 2/10
# 100/100 - 15s - loss: 0.0228 - transformer_loss: 0.0182 - flow_loss: 0.0920 - 15s/epoch - 150ms/step
# Epoch 3/10
# 100/100 - 17s - loss: 0.0183 - transformer_loss: 0.0136 - flow_loss: 0.0929 - 17s/epoch - 165ms/step
# Epoch 4/10
# 100/100 - 16s - loss: 0.0159 - transformer_loss: 0.0113 - flow_loss: 0.0919 - 16s/epoch - 157ms/step
# Epoch 5/10
# 100/100 - 14s - loss: 0.0144 - transformer_loss: 0.0098 - flow_loss: 0.0919 - 14s/epoch - 142ms/step
# Epoch 6/10
# 100/100 - 15s - loss: 0.0134 - transformer_loss: 0.0089 - flow_loss: 0.0891 - 15s/epoch - 147ms/step
# Epoch 7/10
# 100/100 - 17s - loss: 0.0124 - transformer_loss: 0.0080 - flow_loss: 0.0880 - 17s/epoch - 172ms/step
# Epoch 8/10
# 100/100 - 15s - loss: 0.0121 - transformer_loss: 0.0077 - flow_loss: 0.0877 - 15s/epoch - 151ms/step
# Epoch 9/10
# 100/100 - 14s - loss: 0.0114 - transformer_loss: 0.0071 - flow_loss: 0.0858 - 14s/epoch - 137ms/step
# Epoch 10/10
# 100/100 - 15s - loss: 0.0113 - transformer_loss: 0.0070 - flow_loss: 0.0859 - 15s/epoch - 150ms/step

# %%
def plot_history(hist, loss_name='loss'):
    # Simple function to plot training history.
    plt.figure()
    plt.plot(hist.epoch, hist.history[loss_name], '.-')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

plot_history(hist)

# %% [markdown]
# # Registration

# %%
# let's get some data
val_generator = vxm_data_generator(x_val, batch_size = 1)
val_input, _ = next(val_generator)
val_pred = vxm_model.predict(val_input)

# %%
# visualize
images = [img[0, :, :, 0] for img in val_input + val_pred] 
titles = ['moving', 'fixed', 'moved', 'flow']
ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
ne.plot.flow([val_pred[1].squeeze()], width=5);
